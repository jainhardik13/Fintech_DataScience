# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("Updated_Portfolio_Management.csv")
data.head(10)
# Out:
#    Unnamed: 0        Date  NSE_Close  NSE_Return    HUL_Close  HUL_Return  \
# 0           0  2020-01-01   12182.50         NaN  1889.245728         NaN
# 1           1  2020-01-02   12282.20    0.008184  1890.709106    0.000775
# 2           2  2020-01-03   12226.65   -0.004523  1880.367920   -0.005469
# 3           3  2020-01-06   11993.05   -0.019106  1868.661011   -0.006226
# 4           4  2020-01-07   12052.95    0.004995  1873.782837    0.002741
# 5           5  2020-01-08   12025.35   -0.002290  1882.221558    0.004504
# 6           6  2020-01-09   12215.90    0.015846  1887.782471    0.002954
# 7           7  2020-01-10   12256.80    0.003348  1906.269531    0.009793
# 8           8  2020-01-13   12329.55    0.005935  1946.121704    0.020906
# 9           9  2020-01-14   12362.30    0.002656  1959.730835    0.006993
#
#     HDFC_Close  HDFC_Return  HINDALCO_Close  HINDALCO_Return  ...  \
# 0  1278.599976          NaN      211.742905              NaN  ...
# ...

# %%
# Separate the market return and stock return
market_return = data["NSE_Return"]
stock_return = data.drop(columns = ["Date", "NSE_Return"])

# %%
# Define trading days
trading_days = 252

# Calculate average daily return and annual return
avg_daily_return = stock_return.mean()
annual_return = avg_daily_return*252
